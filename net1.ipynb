# %%
import pandas as pd
import numpy as np
import random as rd
from ripser import ripser
from persim import plot_diagrams



data = np.array([[1,0,0],[0,1,0],[0,0,1]])
diagrams = ripser(data, maxdim = 3)['dgms']
print(diagrams)
plot_diagrams(diagrams, show=True)
# Out:
# C:\Users\tarte\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ripser\ripser.py:247: UserWarning: The input matrix is square, but the distance_matrix flag is off.  Did you mean to indicate that this was a distance matrix?
#   warnings.warn(
# [array([[0.        , 1.41421354],
#        [0.        , 1.41421354],
#        [0.        ,        inf]]), array([], shape=(0, 2), dtype=float64), array([], shape=(0, 2), dtype=float64), array([], shape=(0, 2), dtype=float64)]
